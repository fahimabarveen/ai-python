# %%
msg = "hello world"
print(msg)
# Out:
# hello world

# %% [markdown]
# #testing ai jupiter notebook

# %%
# !python -m venv labenv
# %pip install --upgrade typing-extensions
# %pip install python-dotenv azure-identity azure-ai-projects azure-ai-inference
# Out:
# Collecting typing-extensions
#   Downloading typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# Installing collected packages: typing-extensions
# Successfully installed typing-extensions-4.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting azure-identity
#   Downloading azure_identity-1.21.0-py3-none-any.whl.metadata (81 kB)
# Collecting azure-ai-projects
#   Downloading azure_ai_projects-1.0.0b10-py3-none-any.whl.metadata (16 kB)
# Collecting azure-ai-inference
#   Downloading azure_ai_inference-1.0.0b9-py3-none-any.whl.metadata (34 kB)
# Collecting azure-core>=1.31.0 (from azure-identity)
#   Downloading azure_core-1.34.0-py3-none-any.whl.metadata (42 kB)
# Collecting cryptography>=2.5 (from azure-identity)
#   Downloading cryptography-44.0.2-cp39-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting msal>=1.30.0 (from azure-identity)
#   Downloading msal-1.32.3-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity)
#   Downloading msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from azure-identity) (4.13.2)
# Collecting isodate>=0.6.1 (from azure-ai-projects)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting requests>=2.21.0 (from azure-core>=1.31.0->azure-identity)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: six>=1.11.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from azure-core>=1.31.0->azure-identity) (1.17.0)
# Collecting cffi>=1.12 (from cryptography>=2.5->azure-identity)
#   Downloading cffi-1.17.1-cp313-cp313-win_amd64.whl.metadata (1.6 kB)
# Collecting PyJWT<3,>=1.0.0 (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity)
#   Downloading PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting pycparser (from cffi>=1.12->cryptography>=2.5->azure-identity)
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting charset-normalizer<4,>=2 (from requests>=2.21.0->azure-core>=1.31.0->azure-identity)
#   Downloading charset_normalizer-3.4.1-cp313-cp313-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests>=2.21.0->azure-core>=1.31.0->azure-identity)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.21.0->azure-core>=1.31.0->azure-identity)
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.21.0->azure-core>=1.31.0->azure-identity)
#   Downloading certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading azure_identity-1.21.0-py3-none-any.whl (189 kB)
# Downloading azure_ai_projects-1.0.0b10-py3-none-any.whl (200 kB)
# Downloading azure_ai_inference-1.0.0b9-py3-none-any.whl (124 kB)
# Downloading azure_core-1.34.0-py3-none-any.whl (207 kB)
# Downloading cryptography-44.0.2-cp39-abi3-win_amd64.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.2 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/3.2 MB 1.1 MB/s eta 0:00:03
#    --------- ------------------------------ 0.8/3.2 MB 1.1 MB/s eta 0:00:03
#    ------------- -------------------------- 1.0/3.2 MB 1.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.3/3.2 MB 1.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.8/3.2 MB 1.3 MB/s eta 0:00:02
#    -------------------------- ------------- 2.1/3.2 MB 1.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.4/3.2 MB 1.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.9/3.2 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 1.5 MB/s eta 0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading msal-1.32.3-py3-none-any.whl (115 kB)
# Downloading msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Downloading cffi-1.17.1-cp313-cp313-win_amd64.whl (182 kB)
# Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading certifi-2025.4.26-py3-none-any.whl (159 kB)
# Downloading charset_normalizer-3.4.1-cp313-cp313-win_amd64.whl (102 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: urllib3, python-dotenv, PyJWT, pycparser, isodate, idna, charset-normalizer, certifi, requests, cffi, cryptography, azure-core, azure-ai-projects, azure-ai-inference, msal, msal-extensions, azure-identity
# Successfully installed PyJWT-2.10.1 azure-ai-inference-1.0.0b9 azure-ai-projects-1.0.0b10 azure-core-1.34.0 azure-identity-1.21.0 certifi-2025.4.26 cffi-1.17.1 charset-normalizer-3.4.1 cryptography-44.0.2 idna-3.10 isodate-0.7.2 msal-1.32.3 msal-extensions-1.3.1 pycparser-2.22 python-dotenv-1.1.0 requests-2.32.3 urllib3-2.4.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os

# Add references
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
from azure.ai.inference.models import SystemMessage, UserMessage, AssistantMessage


def main(): 

    # Clear the console
    os.system('cls' if os.name=='nt' else 'clear')
        
    try: 
    
        # Get configuration settings 
        load_dotenv()
        project_connection = os.getenv("PROJECT_CONNECTION")
        model_deployment =  os.getenv("MODEL_DEPLOYMENT")
        
        # Initialize the project client
        projectClient = AIProjectClient.from_connection_string(
        conn_str=project_connection,
        credential=DefaultAzureCredential())

        ## Get a chat client 
        chat = projectClient.inference.get_chat_completions_client()

        ## Initialize prompt with system message
        prompt=[
                SystemMessage("You are a helpful AI assistant that answers questions.")
            ]

        # Loop until the user types 'quit'
        while True:
            # Get input text
            input_text = input("Enter the prompt (or type 'quit' to exit): ")
            if input_text.lower() == "quit":
                break
            if len(input_text) == 0:
                print("Please enter a prompt.")
                continue
            
            # Get a chat completion
            prompt.append(UserMessage(input_text))
            response = chat.complete(
            model=model_deployment,
            messages=prompt)
            completion = response.choices[0].message.content
            print(completion)
            prompt.append(AssistantMessage(completion))

    except Exception as ex:
        print(ex)

if __name__ == '__main__': 
    main()
